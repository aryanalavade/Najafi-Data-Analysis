# %%
import deeplabcut
print(deeplabcut.__version__)
# Out:
# Loading DLC 3.0.0rc10...
# 3.0.0rc10

# %%
config = "/storage/scratch1/8/analavade3/FullBodyTracking-Arya-2025-11-17/config.yaml"

# %%
deeplabcut.train_network(config, autotune=False)
# Out:
# Training with configuration:
# data:
#   bbox_margin: 20
#   colormode: RGB
#   inference:
#     normalize_images: True
#   train:
#     affine:
#       p: 0.5
#       rotation: 30
#       scaling: [0.5, 1.25]
#       translation: 0
#     crop_sampling:
#       width: 448
#       height: 448
#       max_shift: 0.1
#       method: hybrid
#     gaussian_noise: 12.75
#     motion_blur: True
#     normalize_images: True
# device: auto
# inference:
#   multithreading:
#     enabled: True
#     queue_length: 4
#     timeout: 30.0
#   compile:
#     enabled: False
#     backend: inductor
#   autocast:
#     enabled: False
# metadata:
#   project_path: /Users/aryan/Desktop/NajafiLab/FullBodyTracking-Arya-2025-11-17
#   pose_config_path: /Users/aryan/Desktop/NajafiLab/FullBodyTracking-Arya-2025-11-17/dlc-models-pytorch/iteration-0/FullBodyTrackingNov17-trainset95shuffle1/train/pytorch_config.yaml
#   bodyparts: ['nose_tip', 'tongue', 'right_forelimb', 'left_forelimb', 'hindlimb', 'whisker_L_root', 'whisker_L_tip', 'whisker_R_root', 'whisker_R_tip', 'pupilLeft', 'pupilTopLeft1', 'pupilTopLeft2', 'pupilTop', 'pupilTopRight1', 'pupilTopRight2', 'pupilRight', 'pupilBottomRight1', 'pupilBottomRight2', 'pupilBottom', 'pupilBottomLeft1', 'pupilBottomLeft2', 'EyeLeft', 'EyeTopLeft1', 'EyeTopleft2', 'EyeTop', 'EyeTopRight1', 'EyeTopRight2', 'EyeRight', 'EyeBottomRight1', 'EyeBottomRight2', 'EyeBottom', 'EyeBottomLeft1', 'EyeBottomLeft2', 'Center']
#   unique_bodyparts: []
#   individuals: ['animal']
#   with_identity: None
# method: bu
# model:
#   backbone:
#     type: ResNet
#     model_name: resnet50_gn
#     output_stride: 16
#     freeze_bn_stats: False
#     freeze_bn_weights: False
#   backbone_output_channels: 2048
#   heads:
#     bodypart:
#       type: HeatmapHead
#       weight_init: normal
#       predictor:
#         type: HeatmapPredictor
#         apply_sigmoid: False
#         clip_scores: True
#         location_refinement: True
#         locref_std: 7.2801
#       target_generator:
#         type: HeatmapGaussianGenerator
#         num_heatmaps: 34
#         pos_dist_thresh: 17
#         heatmap_mode: KEYPOINT
#         gradient_masking: False
#         generate_locref: True
#         locref_std: 7.2801
#       criterion:
#         heatmap:
#           type: WeightedMSECriterion
#           weight: 1.0
#         locref:
#           type: WeightedHuberCriterion
#           weight: 0.05
#       heatmap_config:
#         channels: [2048, 34]
#         kernel_size: [3]
#         strides: [2]
#       locref_config:
#         channels: [2048, 68]
#         kernel_size: [3]
#         strides: [2]
# net_type: resnet_50
# runner:
#   type: PoseTrainingRunner
#   gpus: None
#   key_metric: test.mAP
#   key_metric_asc: True
#   eval_interval: 10
#   optimizer:
#     type: AdamW
#     params:
#       lr: 0.0005
#   scheduler:
#     type: LRListScheduler
#     params:
#       lr_list: [[0.0001], [1e-05]]
#       milestones: [90, 120]
#   snapshots:
#     max_snapshots: 5
#     save_epochs: 50
#     save_optimizer_state: False
# train_settings:
#   batch_size: 32
#   dataloader_workers: 0
#   dataloader_pin_memory: False
#   display_iters: 1000
#   epochs: 200
#   seed: 42
# Loading pretrained weights from Hugging Face hub (timm/resnet50_gn.a1h_in1k)
# HTTP Request: HEAD https://huggingface.co/timm/resnet50_gn.a1h_in1k/resolve/main/model.safetensors "HTTP/1.1 302 Found"
# [timm/resnet50_gn.a1h_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Data Transforms:
#   Training:   Compose([
#   Affine(always_apply=False, p=0.5, interpolation=1, mask_interpolation=0, cval=0, mode=0, scale={'x': (0.5, 1.25), 'y': (0.5, 1.25)}, translate_percent=None, translate_px={'x': (0, 0), 'y': (0, 0)}, rotate=(-30, 30), fit_output=False, shear={'x': (0.0, 0.0), 'y': (0.0, 0.0)}, cval_mask=0, keep_ratio=True, rotate_method='largest_box'),
#   PadIfNeeded(always_apply=True, p=1.0, min_height=448, min_width=448, pad_height_divisor=None, pad_width_divisor=None, position=PositionType.CENTER, border_mode=0, value=None, mask_value=None),
#   KeypointAwareCrop(always_apply=True, p=1.0, width=448, height=448, max_shift=0.1, crop_sampling='hybrid'),
#   MotionBlur(always_apply=False, p=0.5, blur_limit=(3, 7), allow_shifted=True),
#   GaussNoise(always_apply=False, p=0.5, var_limit=(0, 162.5625), per_channel=True, mean=0),
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
# ], p=1.0, bbox_params={'format': 'coco', 'label_fields': ['bbox_labels'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True}, keypoint_params={'format': 'xy', 'label_fields': ['class_labels'], 'remove_invisible': False, 'angle_in_degrees': True, 'check_each_transform': True}, additional_targets={}, is_check_shapes=True)
#   Validation: Compose([
#   Normalize(always_apply=False, p=1.0, mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225], max_pixel_value=255.0),
# ], p=1.0, bbox_params={'format': 'coco', 'label_fields': ['bbox_labels'], 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True}, keypoint_params={'format': 'xy', 'label_fields': ['class_labels'], 'remove_invisible': False, 'angle_in_degrees': True, 'check_each_transform': True}, additional_targets={}, is_check_shapes=True)
# Using 19 images and 1 for testing
#
# Starting pose model training...
# --------------------------------------------------
# Epoch 1/200 (lr=0.0005), train loss 0.01605
# Epoch 2/200 (lr=0.0005), train loss 0.01707
# Epoch 3/200 (lr=0.0005), train loss 0.01504
# Epoch 4/200 (lr=0.0005), train loss 0.01511
# Epoch 5/200 (lr=0.0005), train loss 0.01492
# Epoch 6/200 (lr=0.0005), train loss 0.01472
# Epoch 7/200 (lr=0.0005), train loss 0.01444
# Epoch 8/200 (lr=0.0005), train loss 0.01406
# Epoch 9/200 (lr=0.0005), train loss 0.01371
# Training for epoch 10 done, starting evaluation
# Epoch 10/200 (lr=0.0005), train loss 0.01292, valid loss 0.01243
# Model performance:
#   metrics/test.rmse:          75.57
#   metrics/test.rmse_pcutoff:   4.29
#   metrics/test.mAP:           60.00
#   metrics/test.mAR:           60.00
# Epoch 11/200 (lr=0.0005), train loss 0.01240
# Epoch 12/200 (lr=0.0005), train loss 0.01178
# Epoch 13/200 (lr=0.0005), train loss 0.01108
# Epoch 14/200 (lr=0.0005), train loss 0.01058
# Epoch 15/200 (lr=0.0005), train loss 0.01025
# Epoch 16/200 (lr=0.0005), train loss 0.00925
# Epoch 17/200 (lr=0.0005), train loss 0.00856
# Epoch 18/200 (lr=0.0005), train loss 0.00846
# Epoch 19/200 (lr=0.0005), train loss 0.00751
# Training for epoch 20 done, starting evaluation
# Epoch 20/200 (lr=0.0005), train loss 0.00802, valid loss 0.00743
# Model performance:
#   metrics/test.rmse:          74.90
#   metrics/test.rmse_pcutoff:   3.53
#   metrics/test.mAP:           60.00
#   metrics/test.mAR:           60.00
# Epoch 21/200 (lr=0.0005), train loss 0.00731
# Epoch 22/200 (lr=0.0005), train loss 0.00649
# Epoch 23/200 (lr=0.0005), train loss 0.00632
# Epoch 24/200 (lr=0.0005), train loss 0.00556
# Epoch 25/200 (lr=0.0005), train loss 0.00611
# Epoch 26/200 (lr=0.0005), train loss 0.00596
# Epoch 27/200 (lr=0.0005), train loss 0.00588
# Epoch 28/200 (lr=0.0005), train loss 0.00520
# Epoch 29/200 (lr=0.0005), train loss 0.00525
# Training for epoch 30 done, starting evaluation
# Epoch 30/200 (lr=0.0005), train loss 0.00523, valid loss 0.00541
# Model performance:
#   metrics/test.rmse:          75.15
#   metrics/test.rmse_pcutoff:   3.05
#   metrics/test.mAP:           60.00
#   metrics/test.mAR:           60.00
# Epoch 31/200 (lr=0.0005), train loss 0.00469
# Epoch 32/200 (lr=0.0005), train loss 0.00515
# Epoch 33/200 (lr=0.0005), train loss 0.00502
# Epoch 34/200 (lr=0.0005), train loss 0.00536
# Epoch 35/200 (lr=0.0005), train loss 0.00415
# Epoch 36/200 (lr=0.0005), train loss 0.00431
# Epoch 37/200 (lr=0.0005), train loss 0.00437
# Epoch 38/200 (lr=0.0005), train loss 0.00416
# Epoch 39/200 (lr=0.0005), train loss 0.00409
# Training for epoch 40 done, starting evaluation
# Epoch 40/200 (lr=0.0005), train loss 0.00390, valid loss 0.00479
# Model performance:
#   metrics/test.rmse:          70.59
#   metrics/test.rmse_pcutoff:   2.36
#   metrics/test.mAP:           60.00
#   metrics/test.mAR:           60.00
# Epoch 41/200 (lr=0.0005), train loss 0.00373
# Epoch 42/200 (lr=0.0005), train loss 0.00421
# Epoch 43/200 (lr=0.0005), train loss 0.00440
# Epoch 44/200 (lr=0.0005), train loss 0.00498
# Epoch 45/200 (lr=0.0005), train loss 0.00340
# Epoch 46/200 (lr=0.0005), train loss 0.00406
# Epoch 47/200 (lr=0.0005), train loss 0.00394
# Epoch 48/200 (lr=0.0005), train loss 0.00356
# Epoch 49/200 (lr=0.0005), train loss 0.00410
# Training for epoch 50 done, starting evaluation
# Epoch 50/200 (lr=0.0005), train loss 0.00323, valid loss 0.00494
# Model performance:
#   metrics/test.rmse:          40.34
#   metrics/test.rmse_pcutoff:   3.06
#   metrics/test.mAP:           80.00
#   metrics/test.mAR:           80.00
# Epoch 51/200 (lr=0.0005), train loss 0.00315
# Epoch 52/200 (lr=0.0005), train loss 0.00295
# Epoch 53/200 (lr=0.0005), train loss 0.00306
# Epoch 54/200 (lr=0.0005), train loss 0.00300
# Epoch 55/200 (lr=0.0005), train loss 0.00367
# Epoch 56/200 (lr=0.0005), train loss 0.00370
# Epoch 57/200 (lr=0.0005), train loss 0.00378
# Epoch 58/200 (lr=0.0005), train loss 0.00299
# Epoch 59/200 (lr=0.0005), train loss 0.00304
# Training for epoch 60 done, starting evaluation
# Epoch 60/200 (lr=0.0005), train loss 0.00327, valid loss 0.00432
# Model performance:
#   metrics/test.rmse:          51.40
#   metrics/test.rmse_pcutoff:   3.00
#   metrics/test.mAP:           80.00
#   metrics/test.mAR:           80.00
# Epoch 61/200 (lr=0.0005), train loss 0.00286
# Epoch 62/200 (lr=0.0005), train loss 0.00280
# Epoch 63/200 (lr=0.0005), train loss 0.00276
# Epoch 64/200 (lr=0.0005), train loss 0.00324
# Epoch 65/200 (lr=0.0005), train loss 0.00362
# Epoch 66/200 (lr=0.0005), train loss 0.00362
# Epoch 67/200 (lr=0.0005), train loss 0.00272
# Epoch 68/200 (lr=0.0005), train loss 0.00302
# Epoch 69/200 (lr=0.0005), train loss 0.00290
# Training for epoch 70 done, starting evaluation
# Epoch 70/200 (lr=0.0005), train loss 0.00318, valid loss 0.00464
# Model performance:
#   metrics/test.rmse:          39.77
#   metrics/test.rmse_pcutoff:   2.98
#   metrics/test.mAP:           80.00
#   metrics/test.mAR:           80.00
# Epoch 71/200 (lr=0.0005), train loss 0.00299
# Epoch 72/200 (lr=0.0005), train loss 0.00293
# Epoch 73/200 (lr=0.0005), train loss 0.00317
# Epoch 74/200 (lr=0.0005), train loss 0.00287
# Epoch 75/200 (lr=0.0005), train loss 0.00287
# Epoch 76/200 (lr=0.0005), train loss 0.00248
# Epoch 77/200 (lr=0.0005), train loss 0.00277
# Epoch 78/200 (lr=0.0005), train loss 0.00260
# Epoch 79/200 (lr=0.0005), train loss 0.00280
# Training for epoch 80 done, starting evaluation
# Epoch 80/200 (lr=0.0005), train loss 0.00256, valid loss 0.00454
# Model performance:
#   metrics/test.rmse:          38.99
#   metrics/test.rmse_pcutoff:   3.41
#   metrics/test.mAP:           80.00
#   metrics/test.mAR:           80.00
# Epoch 81/200 (lr=0.0005), train loss 0.00220
# Epoch 82/200 (lr=0.0005), train loss 0.00245
# Epoch 83/200 (lr=0.0005), train loss 0.00248
# Epoch 84/200 (lr=0.0005), train loss 0.00281
# Epoch 85/200 (lr=0.0005), train loss 0.00221
# Epoch 86/200 (lr=0.0005), train loss 0.00271
# Epoch 87/200 (lr=0.0005), train loss 0.00216
# Epoch 88/200 (lr=0.0005), train loss 0.00250
# Epoch 89/200 (lr=0.0005), train loss 0.00278
# Training for epoch 90 done, starting evaluation
# Epoch 90/200 (lr=0.0001), train loss 0.00279, valid loss 0.00375
# Model performance:
#   metrics/test.rmse:          35.89
#   metrics/test.rmse_pcutoff:   2.60
#   metrics/test.mAP:           80.00
#   metrics/test.mAR:           80.00
# Epoch 91/200 (lr=0.0001), train loss 0.00220
# Epoch 92/200 (lr=0.0001), train loss 0.00220
# Epoch 93/200 (lr=0.0001), train loss 0.00245
# Epoch 94/200 (lr=0.0001), train loss 0.00223
# Epoch 95/200 (lr=0.0001), train loss 0.00215
# Epoch 96/200 (lr=0.0001), train loss 0.00193
# Epoch 97/200 (lr=0.0001), train loss 0.00201
# Epoch 98/200 (lr=0.0001), train loss 0.00230
# Epoch 99/200 (lr=0.0001), train loss 0.00199
# Training for epoch 100 done, starting evaluation
# Epoch 100/200 (lr=0.0001), train loss 0.00205, valid loss 0.00376
# Model performance:
#   metrics/test.rmse:          39.23
#   metrics/test.rmse_pcutoff:   2.16
#   metrics/test.mAP:           80.00
#   metrics/test.mAR:           80.00
# Epoch 101/200 (lr=0.0001), train loss 0.00265
# Epoch 102/200 (lr=0.0001), train loss 0.00247
# Epoch 103/200 (lr=0.0001), train loss 0.00183
# Epoch 104/200 (lr=0.0001), train loss 0.00194
# Epoch 105/200 (lr=0.0001), train loss 0.00204
# Epoch 106/200 (lr=0.0001), train loss 0.00193
# Epoch 107/200 (lr=0.0001), train loss 0.00205
# Epoch 108/200 (lr=0.0001), train loss 0.00197
# Epoch 109/200 (lr=0.0001), train loss 0.00214
# Training for epoch 110 done, starting evaluation
# Epoch 110/200 (lr=0.0001), train loss 0.00179, valid loss 0.00376
# Model performance:
#   metrics/test.rmse:          27.65
#   metrics/test.rmse_pcutoff:   2.31
#   metrics/test.mAP:           90.00
#   metrics/test.mAR:           90.00
# Epoch 111/200 (lr=0.0001), train loss 0.00197
# Epoch 112/200 (lr=0.0001), train loss 0.00192
# Epoch 113/200 (lr=0.0001), train loss 0.00186
# Epoch 114/200 (lr=0.0001), train loss 0.00168
# Epoch 115/200 (lr=0.0001), train loss 0.00184
# Epoch 116/200 (lr=0.0001), train loss 0.00145
# Epoch 117/200 (lr=0.0001), train loss 0.00177
# Epoch 118/200 (lr=0.0001), train loss 0.00208
# Epoch 119/200 (lr=0.0001), train loss 0.00168
# Training for epoch 120 done, starting evaluation
# Epoch 120/200 (lr=1e-05), train loss 0.00158, valid loss 0.00365
# Model performance:
#   metrics/test.rmse:          27.04
#   metrics/test.rmse_pcutoff:   2.30
#   metrics/test.mAP:           90.00
#   metrics/test.mAR:           90.00
# Epoch 121/200 (lr=1e-05), train loss 0.00192
# Epoch 122/200 (lr=1e-05), train loss 0.00161
# Epoch 123/200 (lr=1e-05), train loss 0.00190
# Epoch 124/200 (lr=1e-05), train loss 0.00167
# Epoch 125/200 (lr=1e-05), train loss 0.00198
# Epoch 126/200 (lr=1e-05), train loss 0.00203
# Epoch 127/200 (lr=1e-05), train loss 0.00164
# Epoch 128/200 (lr=1e-05), train loss 0.00202
# Epoch 129/200 (lr=1e-05), train loss 0.00220
# Training for epoch 130 done, starting evaluation
# Epoch 130/200 (lr=1e-05), train loss 0.00212, valid loss 0.00358
# Model performance:
#   metrics/test.rmse:          28.34
#   metrics/test.rmse_pcutoff:   2.18
#   metrics/test.mAP:           90.00
#   metrics/test.mAR:           90.00
# Epoch 131/200 (lr=1e-05), train loss 0.00200
# Epoch 132/200 (lr=1e-05), train loss 0.00174
# Epoch 133/200 (lr=1e-05), train loss 0.00151
# Epoch 134/200 (lr=1e-05), train loss 0.00177
# Epoch 135/200 (lr=1e-05), train loss 0.00168
# Epoch 136/200 (lr=1e-05), train loss 0.00172
# Epoch 137/200 (lr=1e-05), train loss 0.00182
# Epoch 138/200 (lr=1e-05), train loss 0.00199
# Epoch 139/200 (lr=1e-05), train loss 0.00179
# Training for epoch 140 done, starting evaluation
# Epoch 140/200 (lr=1e-05), train loss 0.00174, valid loss 0.00363
# Model performance:
#   metrics/test.rmse:          23.60
#   metrics/test.rmse_pcutoff:   2.31
#   metrics/test.mAP:           90.00
#   metrics/test.mAR:           90.00
# Epoch 141/200 (lr=1e-05), train loss 0.00191
# Epoch 142/200 (lr=1e-05), train loss 0.00156
# Epoch 143/200 (lr=1e-05), train loss 0.00167
# Epoch 144/200 (lr=1e-05), train loss 0.00209
# Epoch 145/200 (lr=1e-05), train loss 0.00188
# Epoch 146/200 (lr=1e-05), train loss 0.00199
# Epoch 147/200 (lr=1e-05), train loss 0.00196
# Epoch 148/200 (lr=1e-05), train loss 0.00164
# Epoch 149/200 (lr=1e-05), train loss 0.00161
# Training for epoch 150 done, starting evaluation
# Epoch 150/200 (lr=1e-05), train loss 0.00181, valid loss 0.00368
# Model performance:
#   metrics/test.rmse:          22.77
#   metrics/test.rmse_pcutoff:   2.35
#   metrics/test.mAP:           90.00
#   metrics/test.mAR:           90.00
# Epoch 151/200 (lr=1e-05), train loss 0.00178
# Epoch 152/200 (lr=1e-05), train loss 0.00197
# Epoch 153/200 (lr=1e-05), train loss 0.00179
# Epoch 154/200 (lr=1e-05), train loss 0.00184
# Epoch 155/200 (lr=1e-05), train loss 0.00193
# Epoch 156/200 (lr=1e-05), train loss 0.00187
# Epoch 157/200 (lr=1e-05), train loss 0.00203
# Epoch 158/200 (lr=1e-05), train loss 0.00161
# Epoch 159/200 (lr=1e-05), train loss 0.00200
# Training for epoch 160 done, starting evaluation
# Epoch 160/200 (lr=1e-05), train loss 0.00178, valid loss 0.00363
# Model performance:
#   metrics/test.rmse:          23.60
#   metrics/test.rmse_pcutoff:   2.28
#   metrics/test.mAP:           90.00
#   metrics/test.mAR:           90.00
# Epoch 161/200 (lr=1e-05), train loss 0.00180
# Epoch 162/200 (lr=1e-05), train loss 0.00195
# Epoch 163/200 (lr=1e-05), train loss 0.00181
# Epoch 164/200 (lr=1e-05), train loss 0.00182
# Epoch 165/200 (lr=1e-05), train loss 0.00226
# Epoch 166/200 (lr=1e-05), train loss 0.00230
# Epoch 167/200 (lr=1e-05), train loss 0.00167
# Epoch 168/200 (lr=1e-05), train loss 0.00190
# Epoch 169/200 (lr=1e-05), train loss 0.00204
# Training for epoch 170 done, starting evaluation
# Epoch 170/200 (lr=1e-05), train loss 0.00178, valid loss 0.00365
# Model performance:
#   metrics/test.rmse:          23.61
#   metrics/test.rmse_pcutoff:   2.23
#   metrics/test.mAP:           90.00
#   metrics/test.mAR:           90.00
# Epoch 171/200 (lr=1e-05), train loss 0.00169
# Epoch 172/200 (lr=1e-05), train loss 0.00259
# Epoch 173/200 (lr=1e-05), train loss 0.00169
# Epoch 174/200 (lr=1e-05), train loss 0.00186
# Epoch 175/200 (lr=1e-05), train loss 0.00195
# Epoch 176/200 (lr=1e-05), train loss 0.00154
# Epoch 177/200 (lr=1e-05), train loss 0.00168
# Epoch 178/200 (lr=1e-05), train loss 0.00184
# Epoch 179/200 (lr=1e-05), train loss 0.00220
# Training for epoch 180 done, starting evaluation
# Epoch 180/200 (lr=1e-05), train loss 0.00154, valid loss 0.00367
# Model performance:
#   metrics/test.rmse:          23.62
#   metrics/test.rmse_pcutoff:   2.23
#   metrics/test.mAP:           90.00
#   metrics/test.mAR:           90.00
# Epoch 181/200 (lr=1e-05), train loss 0.00168
# Epoch 182/200 (lr=1e-05), train loss 0.00180
# Epoch 183/200 (lr=1e-05), train loss 0.00237
# Epoch 184/200 (lr=1e-05), train loss 0.00144
# Epoch 185/200 (lr=1e-05), train loss 0.00167
# Epoch 186/200 (lr=1e-05), train loss 0.00164
# Epoch 187/200 (lr=1e-05), train loss 0.00201
# Epoch 188/200 (lr=1e-05), train loss 0.00188
# Epoch 189/200 (lr=1e-05), train loss 0.00190
# Training for epoch 190 done, starting evaluation
# Epoch 190/200 (lr=1e-05), train loss 0.00228, valid loss 0.00365
# Model performance:
#   metrics/test.rmse:          22.68
#   metrics/test.rmse_pcutoff:   2.20
#   metrics/test.mAP:           90.00
#   metrics/test.mAR:           90.00
# Epoch 191/200 (lr=1e-05), train loss 0.00184
# Epoch 192/200 (lr=1e-05), train loss 0.00175
# Epoch 193/200 (lr=1e-05), train loss 0.00172
# Epoch 194/200 (lr=1e-05), train loss 0.00159
# Epoch 195/200 (lr=1e-05), train loss 0.00161
# Epoch 196/200 (lr=1e-05), train loss 0.00180
# Epoch 197/200 (lr=1e-05), train loss 0.00176
# Epoch 198/200 (lr=1e-05), train loss 0.00188
# Epoch 199/200 (lr=1e-05), train loss 0.00161
# Training for epoch 200 done, starting evaluation
# Epoch 200/200 (lr=1e-05), train loss 0.00174, valid loss 0.00361
# Model performance:
#   metrics/test.rmse:          22.66
#   metrics/test.rmse_pcutoff:   2.22
#   metrics/test.mAP:           90.00
#   metrics/test.mAR:           90.00
